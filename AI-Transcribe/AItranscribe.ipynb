# %% [markdown]
# **This will accept .mp4, .mp3, and other audio formats**

# %% [markdown]
# =========================INSTRUCTIONS==============================
#
# **1st step Upload the video for transcription in the AI-Transcibe folder then**
#
# **2nd step Once uploaded Click the play button to mount your Google drive**
#
# ![image.png](data:image/png;base64,...)
#
# ===================================================================

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# =========================INSTRUCTIONS==============================
#
# **3rd step click on the play button to run the code below**
#
# ![image.png](data:image/png;base64,...)
#
# Credits to https://github.com/openai/whisper
# play this code snip
#
# **This installation will not be stored in your computer**
#
# ===================================================================

# %%
# !pip install git+https://github.com/openai/whisper.git
# !sudo apt update && sudo apt install ffmpeg
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-4n8nehsp
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-4n8nehsp
#   Resolved https://github.com/openai/whisper.git to commit c09a7ae299c4c34c5839a76380ae407e7d785914
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 65.4 MB/s eta 0:00:00
# ...
#   Created wheel for openai-whisper: filename=openai_whisper-20230314-py3-none-any.whl size=798038 sha256=ee9ffd28004c80cefb36d5447de265c19c2145439bdda4c417e4716f92f34d73
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ld5w9617/wheels/fe/03/29/e7919208d11b4ab32972cb448bb84a9a675d92cd52c9a48341
# Successfully built openai-whisper
# ...

# %% [markdown]
# =========================INSTRUCTIONS==============================
#
# **4th step In the file explorer on your left, navigate to where you have uploaded the AI-Transcibe folder as shown below**
#
#
# CLICK THE PLAY BUTTON
#
# ![image.png](data:image/png;base64,...)
#
# ==================================================================

# %%
Folder_path = !find -name AI-Transcribe
path = Folder_path[0]

# %cd $path
# Out:
# /content/drive/MyDrive/Colab Notebooks/AI-Transcribe

# %% [markdown]
# =========================INSTRUCTIONS==============================
#
# **Models to choose from listed below**
#
# {tiny.en,tiny,base.en,base,small.en,small,medium.en,medium,large-v1,large-v2,large}
#
#          <----faster/lower accuracy                  slower/higher accuracy---->
#
# To use different models follow the format below:
#
# !whisper "Whole Filename.mp4" --model large-v1
#
# **5th step Replace the filename with the filename of the file you're going to transcribe**
#
# THEN CLICK THE PLAY BUTTON
#
# ==================================================================

# %%
# !whisper "sample.wav" --model medium --output_format vtt
# Out:
# 100%|█████████████████████████████████████| 1.42G/1.42G [00:47<00:00, 32.5MiB/s]
# Detecting language using up to the first 30 seconds. Use `--language` to specify the language
# Detected language: Tagalog
# [00:00.000 --> 00:07.000]  Good day, I'm Jethro Hoytila Cuesta, but you can call me Jeth.
# [00:07.000 --> 00:15.000]  I'm a fifth year computer engineering student specializing with HP UNIX Administration at Mapuwa University.
# [00:15.000 --> 00:20.000]  We are required to accomplish at least 240 hours of internship.
# [00:20.000 --> 00:26.000]  My hobbies include gaming, watching anime, 3D modeling, and making beats.
# [00:26.000 --> 00:39.000]  My skills are Linux bash scripting using Python, C++, C Sharp, basic Cisco configuration, PCB designs, and I can also build and troubleshoot computers.
# [00:39.000 --> 00:48.000]  I expect to enjoy my internship here and that I will be trained to hone my skills so that I can have a great future in the tech industry.
# ...

# %% [markdown]
# =========================INSTRUCTIONS==============================
#
#
# **6th step after the transcription is done go to the file explorer where the file resides shown below. Here youre going to see outputfiles. Double click on the .vtt file**
#
# ![image.png](data:image/png;base64,...)
#
# **7th step copy the contents of the .vtt file paste it first in notepad then copy it to word**
#
# ![image.png](data:image/png;base64,...)
#
# ======================================================================

# %% [markdown]
# Run this for further Instructions about the commands

# %%
# !whisper --help

# %% [markdown]
# regex find and replace '?????--\\>?[0-9][0-9]:[0-9][0-9].[0-9][0-9][0-9]'
#
# ![image.png](data:image/png;base64,...)
